# %%
from collection import SingleLinkedList


sll = SingleLinkedList()
sll.push("a")
sll.push("b")
sll.push("c")
sll.push("d")
sll.push("e")
sll.push("f")

sll.pop()
print(sll)
# Out:
# === Single Linked List ===
# n : 5
# HEAD: e
# node: d
# node: c
# node: b
# TAIL: a

# %%
print(sll.tail.next)

sll.add("x")
sll.add("y")
sll.add("z")

sll.remove()
print(sll)
# Out:
# None
# === Single Linked List ===
# n : 7
# HEAD: d
# node: c
# node: b
# node: a
# node: x
# node: y
# TAIL: z
